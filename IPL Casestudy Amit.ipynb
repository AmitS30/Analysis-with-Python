# %% [markdown]
# # import all libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # read ipl.csv file and print first 5 records

# %%
df=pd.read_csv("ipl data.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#check total number of columns,entries note down your findings

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
#In the dataset we have total 636 entriesof data 
#In the dataset we have 18 columns and 636 rows 
#In the dataset we have three types of datatypes int datatype float datatype and object datatype
#In the dataset there are many columns having null values in it i.e. city column having 7 null values, winner column having 3 null values, player_of_match column having 3 null values umpire1, umpire2 each having one null value and umpire3 is whole null column.
#As umpire 3 is whole null column we can drop it from the dataset.

# %% [markdown]
# # find null values

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
#In the dataset there are many columns having null values in it i.e. city column having 7 null values, winner column having 3 null values, player_of_match column having 3 null values umpire1, umpire2 each having one null value and umpire3 is whole null column.
#As umpire 3 is whole null column we can drop it from the dataset.

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # drop umpire3 column as it contains more than 75% of null values

# %%
df.drop(["umpire3"],axis=1,inplace=True)

# %% [markdown]
# # drop null values of city , winner ,player_of_match,umpire1,umpire2 column

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      index   id  season       city        date                   team1  \
# 0        0    1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1        1    2    2017       Pune  2017-04-06          Mumbai Indians
# 2        2    3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3        3    4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5        5    6    2017  Hyderabad  2017-04-09           Gujarat Lions
# ..     ...  ...     ...        ...         ...                     ...
# 631    631  632    2016     Raipur  2016-05-22        Delhi Daredevils
# 632    632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 633    633  634    2016      Delhi  2016-05-25     Sunrisers Hyderabad
# 634    634  635    2016      Delhi  2016-05-27           Gujarat Lions
# 635    635  636    2016  Bangalore  2016-05-29     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#After dropping all null rows we left with 625 rows and 18 column

# %% [markdown]
# # Which city hosted most number of matches
# #Draw bar plot and your insights

# %%
g=df.groupby("city")["id"].count().sort_values(ascending=False).plot(kind="bar")

# %%
#After looking at the graph we get to know that Mumbai has hosted most number of the matches more than 80 matches have been hosted by Mumbai city

# %%
a=df.groupby("city")

# %% [markdown]
# # Find all venues of mumabi city

# %%
a.get_group("Mumbai")["venue"].unique()
# Out:
# array(['Wankhede Stadium', 'Dr DY Patil Sports Academy',
#        'Brabourne Stadium'], dtype=object)

# %%
#Mumbai has Three different venues in total i.e. Wankhede stadium, Dr DY Patil Sports academy, Braborne Stdium.

# %% [markdown]
# # Now compare in which venue of mumbai most number of matches played (draw bar plot and  write down insights)

# %%
s=a.get_group("Mumbai")
s
# Out:
#      index   id  season    city        date                        team1  \
# 6        6    7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9        9   10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15      15   16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23      23   24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27      27   28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..     ...  ...     ...     ...         ...                          ...
# 572    572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576    576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584    584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589    589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599    599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# ...

# %%
h=s.groupby("venue")["id"].count().sort_values(ascending=False).plot(kind="bar")

# %%
#The wankhede stadium venue of mumbai has hosted most number of matches as compared to the other venues of the Mumbai the total is more than 50 and after that comes Dr DY Patil Academy with more than 10 and last it comes to Brabourne stadium

# %% [markdown]
# # what is the preferred choice after winning a toss in mumbai

# %%
ab=a.get_group("Mumbai")

# %%
j=ab.groupby('toss_decision')['id'].count()

# %%
j
# Out:
# toss_decision
# bat      34
# field    51
# Name: id, dtype: int64

# %% [markdown]
# # Graphical representation of the above question

# %%
h=ab.groupby("toss_decision")["id"].count().plot(kind="bar")

# %%
#After making the graphical representation we got to know that approximately 50 times teams have chosen fielding in Mumbai after winning the toss

# %% [markdown]
# # Which team won most number of toss

# %%
df["winner"].sort_values().value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
d=df.groupby("toss_winner")["id"].count().sort_values(ascending=False)

# %%
d
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: id, dtype: int64

# %%
h=df.groupby("toss_winner")["id"].count().sort_values(ascending=False).plot(kind="bar")

# %% [markdown]
# # Find what mumbai indians preferred after winning a toss

# %%
s1=df.groupby("toss_winner")

# %%
s1

# %%
s2=s1.get_group("Mumbai Indians")["toss_decision"].value_counts()

# %%
s2
# Out:
# field    45
# bat      40
# Name: toss_decision, dtype: int64

# %%
#Mumbai Indians have chosen fielding most of the time after winning the toss and chose batting 40 times.

# %% [markdown]
# # Head to head winning count of Mumbai Indians vs Chennai Super Kings

# %%
df[((df["team1"]=="Mumbai Indians")|(df["team1"]=="Chennai Super Kings"))&((df["team2"]=="Mumbai Indians")|(df["team2"]=="Chennai Super Kings"))]["winner"].value_counts()
# Out:
# Mumbai Indians         12
# Chennai Super Kings    10
# Name: winner, dtype: int64

# %%
#In the head to thead match mumbai have upper hand and has won 12 matches and chennai has won 10 matches against mumbai

# %% [markdown]
# # Which team has won most number of matches in mumbai

# %%
d=a.get_group("Mumbai")["winner"].value_counts()

# %%
d
# Out:
# Mumbai Indians                 45
# Chennai Super Kings             8
# Kings XI Punjab                 5
# Royal Challengers Bangalore     5
# Rajasthan Royals                5
# Deccan Chargers                 3
# Kolkata Knight Riders           3
# Pune Warriors                   3
# Rising Pune Supergiant          2
# Delhi Daredevils                2
# Kochi Tuskers Kerala            1
# Sunrisers Hyderabad             1
# Rising Pune Supergiants         1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
#Mumbai Indians have won 45 times in Mumbai the most by any team than others

# %% [markdown]
# # How many times each team won the toss and won the match

# %%
s=df[(df["toss_winner"]==df["winner"])]

# %%
s
# Out:
#      index   id  season       city        date                   team1  \
# 1        1    2    2017       Pune  2017-04-06          Mumbai Indians
# 2        2    3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3        3    4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5        5    6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6        6    7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...  ...     ...        ...         ...                     ...
# 629    629  630    2016     Kanpur  2016-05-21          Mumbai Indians
# 631    631  632    2016     Raipur  2016-05-22        Delhi Daredevils
# 632    632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 634    634  635    2016      Delhi  2016-05-27           Gujarat Lions
# 635    635  636    2016  Bangalore  2016-05-29     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
s.groupby("winner")["id"].count()
# Out:
# winner
# Chennai Super Kings            42
# Deccan Chargers                19
# Delhi Daredevils               33
# Gujarat Lions                  10
# Kings XI Punjab                27
# Kochi Tuskers Kerala            4
# Kolkata Knight Riders          44
# Mumbai Indians                 48
# Pune Warriors                   3
# Rajasthan Royals               34
# Rising Pune Supergiant          5
# Rising Pune Supergiants         3
# Royal Challengers Bangalore    33
# Sunrisers Hyderabad            16
# Name: id, dtype: int64

# %%
#48 Times Mumbai Indians have won the toss and match also.

# %% [markdown]
# # How many times each team won the toss and won the match in mumbai

# %%
j=df[(df["toss_winner"]==df["winner"])&(df["city"]=="Mumbai")]

# %%
j
# Out:
#      index   id  season    city        date                        team1  \
# 6        6    7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9        9   10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15      15   16    2017  Mumbai  2017-04-16                Gujarat Lions
# 71      71   72    2008  Mumbai  2008-04-27               Mumbai Indians
# 85      85   86    2008  Mumbai  2008-05-07             Rajasthan Royals
# 95      95   96    2008  Mumbai  2008-05-14          Chennai Super Kings
# 98      98   99    2008  Mumbai  2008-05-16        Kolkata Knight Riders
# 116    116  117    2008  Mumbai  2008-06-01          Chennai Super Kings
# 175    175  176    2010  Mumbai  2010-03-13               Mumbai Indians
# 193    193  194    2010  Mumbai  2010-03-25          Chennai Super Kings
# 200    200  201    2010  Mumbai  2010-03-30              Kings XI Punjab
# 206    206  207    2010  Mumbai  2010-04-03               Mumbai Indians
# ...

# %% [markdown]
# # Which venue hosted most number of matches

# %%
plt.figure(figsize=(10,10))
df.groupby("venue")["id"].count().sort_values(ascending=False).plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='venue'>

# %%
#MChinnaswami Stadium has hosted most number of matches in total.

# %% [markdown]
# # find how many matches chennai super kings played at M Chinnaswamy stadium?

# %%
v=df.groupby("venue")

# %%
b=df[(df["team1"]=="Chennai Super Kings")|(df["team2"]=="Chennai Super Kings")]
b
# Out:
#      index   id  season        city        date                        team1  \
# 60      60   61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 66      66   67    2008     Chennai  2008-04-23          Chennai Super Kings
# 70      70   71    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 73      73   74    2008   Bangalore  2008-04-28          Chennai Super Kings
# 78      78   79    2008     Chennai  2008-05-02          Chennai Super Kings
# ..     ...  ...     ...         ...         ...                          ...
# 564    564  565    2015      Raipur  2015-05-12          Chennai Super Kings
# 568    568  569    2015  Chandigarh  2015-05-16              Kings XI Punjab
# 572    572  573    2015      Mumbai  2015-05-19               Mumbai Indians
# 574    574  575    2015      Ranchi  2015-05-22  Royal Challengers Bangalore
# 575    575  576    2015     Kolkata  2015-05-24               Mumbai Indians
#
# ...

# %%
c=b[b["venue"]=="M Chinnaswamy Stadium"]["id"].count()
c
# Out:
# 7

# %%
#Chennai super kings have played 7 matches at M chinnaswami stadium.

# %% [markdown]
# # Who won most number of matches at M Chinnaswamy stadium

# %%
a=df.groupby("venue")

# %%
a1=a.get_group("M Chinnaswamy Stadium")["winner"].value_counts()

# %%
 a1
# Out:
# Royal Challengers Bangalore    30
# Mumbai Indians                  8
# Kolkata Knight Riders           6
# Kings XI Punjab                 5
# Chennai Super Kings             4
# Rajasthan Royals                3
# Delhi Daredevils                3
# Sunrisers Hyderabad             2
# Rising Pune Supergiant          1
# Gujarat Lions                   1
# Deccan Chargers                 1
# Name: winner, dtype: int64

# %%
#Royal Challengers Bangalore have won 30 matches at M Chinnaswami stadium

# %% [markdown]
# # YEAR WISE ANALYSIS

# %%
#matches played in each year

# %%
#lets analyse ipl season held in 2013
#extract all the details of 2013 season
#here we will create yearwise groups (hint: use groupby() function)

# %%
df[df["season"]==2013]
# Out:
#      index   id  season       city        date                        team1  \
# 381    381  382    2013    Kolkata  2013-04-03             Delhi Daredevils
# 382    382  383    2013  Bangalore  2013-04-04  Royal Challengers Bangalore
# 383    383  384    2013  Hyderabad  2013-04-05          Sunrisers Hyderabad
# 384    384  385    2013      Delhi  2013-04-06             Rajasthan Royals
# 385    385  386    2013    Chennai  2013-04-06               Mumbai Indians
# ..     ...  ...     ...        ...         ...                          ...
# 452    452  453    2013  Hyderabad  2013-05-19        Kolkata Knight Riders
# 453    453  454    2013      Delhi  2013-05-21          Chennai Super Kings
# 454    454  455    2013      Delhi  2013-05-22          Sunrisers Hyderabad
# 455    455  456    2013    Kolkata  2013-05-24             Rajasthan Royals
# 456    456  457    2013    Kolkata  2013-05-26               Mumbai Indians
#
# ...

# %% [markdown]
# # Which city hosted most number of matches in 2013

# %%
df[df["season"]==2013]["city"].value_counts()
# Out:
# Kolkata       8
# Bangalore     8
# Hyderabad     8
# Delhi         8
# Chennai       8
# Pune          8
# Jaipur        8
# Mumbai        8
# Chandigarh    6
# Dharamsala    2
# Raipur        2
# Ranchi        2
# Name: city, dtype: int64

# %%
#Its tie between total of 8 teams. All the 8 teams have won 8 matches each in Year 2013.
