# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read the file and give description about the dataset

# %%
df=pd.read_csv("Egypt_Houses_Price.csv")
df
# Out:
#                     Type     Price Bedrooms Bathrooms   Area Furnished  \
# 0                 Duplex   4000000      3.0       3.0  400.0        No
# 1              Apartment   4000000      3.0       3.0  160.0        No
# 2              Apartment   2250000      3.0       2.0  165.0        No
# 3              Apartment   1900000      3.0       2.0  230.0        No
# 4              Apartment   5800000      2.0       3.0  160.0        No
# ...                  ...       ...      ...       ...    ...       ...
# 27356         Town House    890000      3.0       2.0  240.0   Unknown
# 27357         Town House   4000000      4.0       3.0  218.0   Unknown
# 27358         Twin House  13800000      3.0       4.0  308.0        No
# 27359  Stand Alone Villa  35000000      4.0       4.0  478.0   Unknown
# 27360  Stand Alone Villa   4800000      5.0       5.0    NaN        No
#
#          Level             Compound       Payment_Option  Delivery_Date  \
# ...

# %% [markdown]
# # Insights
# #The following dataset we having is about The Egypt Houses which are for sale. <br>
# #In the dataset we have the brief info about the houses like the house is furnished or not, the area of the house and number of bathrooms bedrooms,etc.<br>
# #The availability of the houses also in the data.<br>

# %% [markdown]
# # Show Top 5 records

# %%
df.head()
# Out:
#         Type    Price Bedrooms Bathrooms   Area Furnished   Level Compound  \
# 0     Duplex  4000000      3.0       3.0  400.0        No       7  Unknown
# 1  Apartment  4000000      3.0       3.0  160.0        No     10+  Unknown
# 2  Apartment  2250000      3.0       2.0  165.0        No       1  Unknown
# 3  Apartment  1900000      3.0       2.0  230.0        No      10  Unknown
# 4  Apartment  5800000      2.0       3.0  160.0        No  Ground  Eastown
#
#   Payment_Option  Delivery_Date  Delivery_Term                    City
# 0           Cash  Ready to move       Finished               Nasr City
# 1           Cash  Ready to move       Finished             Camp Caesar
# 2           Cash  Ready to move       Finished                   Smoha
# 3           Cash  Ready to move       Finished               Nasr City
# 4           Cash  Ready to move  Semi Finished  New Cairo - El Tagamoa

# %%
df.describe()
# Out:
#              Type    Price Bedrooms Bathrooms   Area Furnished    Level  \
# count       27361    27359    27158     27190  26890     27361    27361
# unique         11     4182       22        22   1073         3       14
# top     Apartment  3000000        3         2  120.0        No  Unknown
# freq         8506      311     9784      7753    663     16500    10439
#
#        Compound       Payment_Option  Delivery_Date Delivery_Term  \
# count     27361                27361          27361         27361
# unique      560                    4             10             5
# top     Unknown  Cash or Installment  Ready to move      Finished
# freq      11068                10842          12142         14375
#
#                           City
# count                    27361
# unique                     183
# top     New Cairo - El Tagamoa
# freq                      6789

# %% [markdown]
# # Check the total number of the dataset and write your insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27361 entries, 0 to 27360
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            27361 non-null  object
#  1   Price           27359 non-null  object
#  2   Bedrooms        27158 non-null  object
#  3   Bathrooms       27190 non-null  object
#  4   Area            26890 non-null  object
#  5   Furnished       27361 non-null  object
#  6   Level           27361 non-null  object
#  7   Compound        27361 non-null  object
#  8   Payment_Option  27361 non-null  object
#  9   Delivery_Date   27361 non-null  object
#  10  Delivery_Term   27361 non-null  object
#  11  City            27361 non-null  object
# dtypes: object(12)
# memory usage: 2.5+ MB

# %% [markdown]
# # Insights
# #In the dataset we have 12 columns and 27360 values in total.<br>
# #We also have some null values in the dataset.<br>
# #We have one problem in our dataset that all the columns having same dtype even the numeric value column also having the object data type.<br>
# #We have to change the particular column datatype which having numeric values.

# %% [markdown]
# # Check the total null values and also the percentage of the null values

# %%
df.isnull().sum()
# Out:
# Type                0
# Price               2
# Bedrooms          203
# Bathrooms         171
# Area              471
# Furnished           0
# Level               0
# Compound            0
# Payment_Option      0
# Delivery_Date       0
# Delivery_Term       0
# City                0
# dtype: int64

# %% [markdown]
# # Insights
# #In the dataset we have few null values present in some columns<br>
# #We have most number of missing data from Area column having 471 null values.<br>
# #There are missing values in bedroom bathroom and price columns having null values 203,171 and 2 respectively.

# %%
df.isnull().sum()/len(df)*100
# Out:
# Type              0.000000
# Price             0.007310
# Bedrooms          0.741932
# Bathrooms         0.624977
# Area              1.721428
# Furnished         0.000000
# Level             0.000000
# Compound          0.000000
# Payment_Option    0.000000
# Delivery_Date     0.000000
# Delivery_Term     0.000000
# City              0.000000
# dtype: float64

# %% [markdown]
# # Insights
# #The missing data percentage is less than 2% we can neglect those values and drop them.

# %% [markdown]
# # Check the data type of the columns and write your insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27361 entries, 0 to 27360
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            27361 non-null  object
#  1   Price           27359 non-null  object
#  2   Bedrooms        27158 non-null  object
#  3   Bathrooms       27190 non-null  object
#  4   Area            26890 non-null  object
#  5   Furnished       27361 non-null  object
#  6   Level           27361 non-null  object
#  7   Compound        27361 non-null  object
#  8   Payment_Option  27361 non-null  object
#  9   Delivery_Date   27361 non-null  object
#  10  Delivery_Term   27361 non-null  object
#  11  City            27361 non-null  object
# dtypes: object(12)
# memory usage: 2.5+ MB

# %% [markdown]
# # Insights
# #As we early discussed we have a problem in the dataset that all the columns having object Dtype. Columns such as price and bedroom count columns having numeric data also having the object dtype so first we have to change the dtype of the those columns and then we can perform the various operations on the dataset.

# %%
df.replace("Unknown",0,inplace=True)

# %%
df["Level"].unique()
# Out:
# array(['7', '10+', '1', '10', 'Ground', 'Highest', '3', '2', '4', '9',
#        '5', '8', '6', 0], dtype=object)

# %%
df['Level']=df['Level'].str.replace("+","")

# %%
df['Level']=df['Level'].str.replace("Ground","1")

# %%
df['Bedrooms']=df['Bedrooms'].str.replace("+","")

# %%
df['Bathrooms']=df['Bathrooms'].str.replace("+","")

# %%
#Change the datatypes of the columns.

# %%
df['Price']=df['Price'].astype("float")

# %%
df["Bedrooms"]=df["Bedrooms"].astype("float")

# %%
df["Bathrooms"]=df["Bathrooms"].astype("float")

# %%
df["Area"]=df["Area"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27361 entries, 0 to 27360
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            27361 non-null  object
#  1   Price           27359 non-null  float64
#  2   Bedrooms        27122 non-null  float64
#  3   Bathrooms       27154 non-null  float64
#  4   Area            26890 non-null  float64
#  5   Furnished       27361 non-null  object
#  6   Level           16922 non-null  object
#  7   Compound        27361 non-null  object
#  8   Payment_Option  27361 non-null  object
#  9   Delivery_Date   27361 non-null  object
#  10  Delivery_Term   27361 non-null  object
#  11  City            27361 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 2.5+ MB

# %%
df.isnull().sum()
# Out:
# Type                  0
# Price                 2
# Bedrooms            239
# Bathrooms           207
# Area                471
# Furnished             0
# Level             10439
# Compound              0
# Payment_Option        0
# Delivery_Date         0
# Delivery_Term         0
# City                  0
# dtype: int64

# %% [markdown]
# # Drop the null values

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Type              0
# Price             0
# Bedrooms          0
# Bathrooms         0
# Area              0
# Furnished         0
# Level             0
# Compound          0
# Payment_Option    0
# Delivery_Date     0
# Delivery_Term     0
# City              0
# dtype: int64

# %% [markdown]
# # Find out the how many houses are ready to move.

# %%
df[df["Delivery_Date"]=="Ready to move"]
# Out:
#                    Type       Price  Bedrooms  Bathrooms   Area Furnished  \
# 0                Duplex   4000000.0       3.0        3.0  400.0        No
# 1             Apartment   4000000.0       3.0        3.0  160.0        No
# 2             Apartment   2250000.0       3.0        2.0  165.0        No
# 3             Apartment   1900000.0       3.0        2.0  230.0        No
# 4             Apartment   5800000.0       2.0        3.0  160.0        No
# ...                 ...         ...       ...        ...    ...       ...
# 18427  Standalone Villa   3200000.0       3.0        3.0  271.0       Yes
# 18439  Standalone Villa  20430000.0       5.0        5.0  320.0        No
# 18443            Chalet   2873000.0       3.0        2.0  115.0         0
# 18446            Chalet    430000.0       1.0        2.0   58.0       Yes
# 18448            Chalet   2800000.0       3.0        2.0  113.0        No
#
#       Level                   Compound       Payment_Option  Delivery_Date  \
# ...

# %% [markdown]
# # Insights
# So there are total 7015 locations which are ready to move.

# %% [markdown]
# # Find out how many Delivery terms are finished

# %%
df[df["Delivery_Term"]=="Finished"]
# Out:
#                    Type       Price  Bedrooms  Bathrooms   Area Furnished  \
# 0                Duplex   4000000.0       3.0        3.0  400.0        No
# 1             Apartment   4000000.0       3.0        3.0  160.0        No
# 2             Apartment   2250000.0       3.0        2.0  165.0        No
# 3             Apartment   1900000.0       3.0        2.0  230.0        No
# 6                Duplex   3900000.0       5.0        5.0  290.0        No
# ...                 ...         ...       ...        ...    ...       ...
# 18439  Standalone Villa  20430000.0       5.0        5.0  320.0        No
# 18443            Chalet   2873000.0       3.0        2.0  115.0         0
# 18446            Chalet    430000.0       1.0        2.0   58.0       Yes
# 18449            Studio    300000.0       1.0        1.0   40.0         0
# 18450            Chalet   2900000.0       3.0        2.0  115.0        No
#
#          Level Compound       Payment_Option  Delivery_Date Delivery_Term  \
# ...

# %%
#Insights
There are 10516 locations which having delivery term finished.

# %% [markdown]
# # Find out the minimum, maximum and average price of the houses.

# %%
df["Price"].max()
# Out:
# 75000000.0

# %%
df["Price"].mean()
# Out:
# 2490862.805941883

# %%
df["Price"].min()
# Out:
# 30000.0

# %% [markdown]
# # Insights
# The minimum price of house is 30000 maximum is 75000000 and the average price is 2490862.80.

# %% [markdown]
# # Which Type of house has biggest area.

# %%
a=df.groupby("Type")

# %%
b=a["Area"].max()
b
# Out:
# Type
# Apartment           855.0
# Chalet              610.0
# Duplex              700.0
# Penthouse           729.0
# Standalone Villa    985.0
# Studio              190.0
# Town House          567.0
# Twin house          581.0
# Name: Area, dtype: float64

# %% [markdown]
# # Insights
# Apartments having the largest area amongst the all types of houses.

# %% [markdown]
# # Which type of house is costly amongst them.

# %%
c=a["Price"].max()
c
# Out:
# Type
# Apartment           42000000.0
# Chalet              69000000.0
# Duplex              24000000.0
# Penthouse           25000000.0
# Standalone Villa    75000000.0
# Studio               6500000.0
# Town House          17500000.0
# Twin house          20000000.0
# Name: Price, dtype: float64

# %% [markdown]
# # Insights
# Apartment having the highest price along with the area.

# %% [markdown]
# # How many location has only Cash mode of payment.

# %%
df[df["Payment_Option"]=="Cash"]
# Out:
#                    Type      Price  Bedrooms  Bathrooms   Area Furnished  \
# 0                Duplex  4000000.0       3.0        3.0  400.0        No
# 1             Apartment  4000000.0       3.0        3.0  160.0        No
# 2             Apartment  2250000.0       3.0        2.0  165.0        No
# 3             Apartment  1900000.0       3.0        2.0  230.0        No
# 4             Apartment  5800000.0       2.0        3.0  160.0        No
# ...                 ...        ...       ...        ...    ...       ...
# 18420            Chalet  6000000.0       3.0        2.0  215.0       Yes
# 18425        Twin house  3200000.0       3.0        3.0  138.0        No
# 18427  Standalone Villa  3200000.0       3.0        3.0  271.0       Yes
# 18446            Chalet   430000.0       1.0        2.0   58.0       Yes
# 18448            Chalet  2800000.0       3.0        2.0  113.0        No
#
#       Level                   Compound Payment_Option  Delivery_Date  \
# ...

# %% [markdown]
# # Insights
# There are 5489 records which acepts only cash mode of payment.

# %% [markdown]
# # Find out records where mode of payment is installment.

# %%
df[df["Payment_Option"]=="Installment"]
# Out:
#              Type      Price  Bedrooms  Bathrooms   Area Furnished Level  \
# 19         Duplex  1100000.0       3.0        2.0  165.0         0     1
# 29      Apartment  1040000.0       3.0        3.0  164.0        No     1
# 32      Apartment   970669.0       3.0        2.0  163.0        No     1
# 37      Apartment  3100000.0       3.0        2.0  200.0         0     1
# 38      Apartment  1368000.0       3.0        3.0  169.0        No     1
# ...           ...        ...       ...        ...    ...       ...   ...
# 18426      Chalet  2335000.0       2.0        3.0  125.0        No     1
# 18431      Chalet  2800000.0       3.0        2.0  129.0        No     2
# 18436      Chalet  3300000.0       3.0        3.0  170.0        No     1
# 18442  Twin house  4700000.0       4.0        4.0  340.0        No     1
# 18450      Chalet  2900000.0       3.0        2.0  115.0        No     1
#
#       Compound Payment_Option  Delivery_Date  Delivery_Term  \
# ...

# %% [markdown]
# # Insights
# There are 2488 records which accepts installments mode of payment.

# %% [markdown]
# # How many locations accepts both cash and installments mode of payment.

# %%
df[df["Payment_Option"]=="Cash or Installment"]
# Out:
#                    Type       Price  Bedrooms  Bathrooms   Area Furnished  \
# 5             Apartment   1844900.0       4.0        3.0  222.0        No
# 9             Apartment    992800.0       3.0        2.0  146.0         0
# 10            Apartment    309825.0       4.0        3.0  153.0        No
# 13            Apartment   2600000.0       3.0        2.0  140.0       Yes
# 15            Apartment    480000.0       3.0        3.0  167.0         0
# ...                 ...         ...       ...        ...    ...       ...
# 18434            Chalet   3140000.0       3.0        2.0  126.0       Yes
# 18435  Standalone Villa  10695000.0       5.0        4.0  304.0        No
# 18438  Standalone Villa  13750000.0       5.0        3.0  280.0        No
# 18443            Chalet   2873000.0       3.0        2.0  115.0         0
# 18449            Studio    300000.0       1.0        1.0   40.0         0
#
#       Level       Compound       Payment_Option  Delivery_Date  Delivery_Term  \
# ...

# %% [markdown]
# # Insights
# There are total 7284 records of location which accepts both cash and installment modes of payment.

# %% [markdown]
# # Graphically show which type of payment option is used the most.

# %%
sns.countplot(df['Payment_Option'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insights
# The most used type of payment is cash or installment

# %% [markdown]
# # Show the Delivery terms in graphical representation.

# %%
sns.countplot(df["Delivery_Term"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insights
# There are more than 10000 of records having delivery term finished and its the highest amongst all others.

# %% [markdown]
# # What is the percentage of number of bedrooms

# %%
plt.figure(figsize=(6,7))
df['Bedrooms'].value_counts().plot.pie(autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Insights
# The percentage of rooms having three and two bedrooms is more in dataset.

# %% [markdown]
# # Show the pie chart of the bathrooms

# %%
plt.figure(figsize=(6,7))
df['Bathrooms'].value_counts().plot.pie(autopct="%1.2f%%")
plt.show()

# %% [markdown]
# # Insights
# The percentage of rooms having 1 to 3 bathrooms is more than rest of the rooms.

# %% [markdown]
# # Show the correlation between the data.

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>
